# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager

# Start browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

driver.get("https://formsmarts.com/html-form-example")
    wait = WebDriverWait(driver, 15)

# %%
iframe = wait.until(
        EC.presence_of_element_located((By.TAG_NAME, "iframe"))
)   
driver.switch_to.frame(iframe)

# %%
wait.until(EC.visibility_of_element_located((By.NAME, "u_7t0_4607"))).send_keys("John")

# %%
wait.until(EC.visibility_of_element_located((By.NAME, "first_name"))).send_keys("John")
